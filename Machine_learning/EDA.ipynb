# %% [markdown]
# #  ___________________ EDA ATTRITION AI _______________

# %%
import pandas as pd

df = pd.read_csv('/Users/miriambenali/Desktop/Project-Simplon/RetentionAI/data/dt.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ###### je constate après l'affichage de head de data que nous avons des column qui pourront avoir des valeurs constantes comme [EmployeeCount]

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ###### je constate que nous avons des valeurs manqués, aussi l'écart type est un peu grand dans certaines columns qui peut se jusfier que nous pouvons avoir des outliers,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().all()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
num_cols = df.select_dtypes(include='number').columns
print(num_cols)
df[num_cols]= df[num_cols].fillna(df[num_cols].mean())
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
cat_cols= df.select_dtypes(include='object').columns
print(cat_cols)
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
#afficher les noms des columns vides

num_cols = df.select_dtypes(include='number')
empty_cols = [col for col in num_cols if df[col].nunique() <= 1 or df[col].isna().all()]
print("Colonnes vides ou constantes :", empty_cols)
# Out:
# Colonnes vides ou constantes : ['EmployeeCount', 'StandardHours']

# %%
df = df.copy()
df = df.drop(columns=empty_cols)

# %% [markdown]
# ## .____________________________ Visualisation________________________________

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_palette("Set2") 

cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 
        'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

fig, axes = plt.subplots(2, 4, figsize=(22, 12))  
axes = axes.flatten() 

for i, col in enumerate(cols):
    sns.countplot(x=col, hue='Attrition', data=df, ax=axes[i])
    axes[i].set_title(f'{col} vs Attrition', fontsize=14, fontweight='bold')
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].legend(title='Attrition', fontsize=10, title_fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
#  après l'observation avec countplot je constate qu' il ya plus de NON que de OUI chose qui signifie que notre data n'est pas equilibré

# %%
cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 
        'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# Créer une figure avec 2 lignes et 4 colonnes
fig, axes = plt.subplots(2, 4, figsize=(22, 12))
axes = axes.flatten()

for i, col in enumerate(cols):
    sns.boxplot(x=col, y='Age', hue='Attrition', data=df, ax=axes[i])  
    axes[i].set_title(f'{col} vs Attrition', fontsize=14, fontweight='bold')
    axes[i].tick_params(axis='x', rotation=45, labelsize=10)
    axes[i].legend(title='Attrition', fontsize=10, title_fontsize=12)

plt.tight_layout()
plt.show()

# %%
df['Attrition']=df['Attrition'].map({'No':0,'Yes': 1})

print(df['Attrition'])
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %% [markdown]
#  Feature Attrition est de type object donc on doit le encoder pour faire une matrice correlation

# %%
encoded_freatures =[
    'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance'
] #ces features sont categoriels mais encoded donc on va les éliminés

# Sélection des colonnes numériques exepct encoded_features
num_cols = df.select_dtypes(include='number').drop(columns= encoded_freatures)

# matrice de correlation
corr_matrix = num_cols.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Matrice de correlation')
plt.show()

# %% [markdown]
# #après l'observation de la matrice je constate qu'il ya des column qu'ils ont une baise correlation
# solution proposée:
# je vais les dropés vu qu' il n y a pas de forte correlation et il ne vont pas impacter sur le résultat

# %%
df = df.drop(columns=['EmployeeNumber','YearsSinceLastPromotion','DailyRate','DistanceFromHome','EmployeeNumber','HourlyRate','MonthlyRate',
                      'NumCompaniesWorked','PercentSalaryHike','TrainingTimesLastYear','YearsSinceLastPromotion'])

# %%
print(df.columns.tolist())
print(f"Nombre total de features initiales : {len(df.columns)}")
# Out:
# ['Age', 'Attrition', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager']
# Nombre total de features initiales : 24

# %% [markdown]
# ## .____________________________ Preprocessing________________________________

# %%
selected_features = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction',
                     'PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']


#identifier les columns

num_cols = (x.select_dtypes(include=['int64', 'float64']).drop(columns=selected_features).columns)
cat_cols = list(set(x.select_dtypes(include='object').columns).union(selected_features))

print(num_cols)
print(cat_cols)
# Out:
# Index(['Age', 'JobLevel', 'MonthlyIncome', 'StockOptionLevel',
#        'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsWithCurrManager'],
#       dtype='object')
# ['Gender', 'Education', 'JobSatisfaction', 'OverTime', 'RelationshipSatisfaction', 'JobInvolvement', 'JobRole', 'PerformanceRating', 'EducationField', 'MaritalStatus', 'Department', 'Over18', 'WorkLifeBalance', 'BusinessTravel', 'EnvironmentSatisfaction']

# %% [markdown]
# cette list de features ont une valeur numérique mais a la base ils sont catégorial
# solution:
# je l'ai eliminé de des columns numerique et les ajoutés au columns categoriels

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report, roc_curve


#preparation des donnés
#x contient toutes les features (variables explicatives) et y contient la target (Attrition)
x = df.drop(['Attrition'], axis=1)
y = df['Attrition']


#transformer Attrition de Yes/No en 0/1
le= LabelEncoder()
y = le.fit_transform(y)
print(len(y))



#80% des données pour l’entraînement, 20% pour le test
X_train, X_test, y_train, y_test = train_test_split(
    x,y,
    test_size =0.2,
    random_state= 42,)


preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(drop='first'), cat_cols)
    ]
)

#définir les modèles à tester avec leurs hyperparamètres
models ={
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "RandomForest": RandomForestClassifier(random_state=42)

}

param_grids = {
    "LogisticRegression": {
        'model__C': [0.01, 0.1, 1, 10]
    },
    "RandomForest": {
        'model__n_estimators': [200, 500],
        'model__max_depth': [4, 5, 6, 7, 8],
        'model__criterion':['gini', 'entropy']
    }
}

for name, model in models.items():

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])

    grid_search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grids[name],
        cv=5,
        scoring='roc_auc',
        n_jobs=-1
    )

    grid_search.fit(X_train, y_train)
    
    #best model
    best_model = grid_search.best_estimator_

    print(f"\n {name}")
    print("Best params:", grid_search.best_params_)
    print("Best score:" ,grid_search.best_score_)


    #évalutation
    y_pred = best_model.predict(X_test)
    y_proba = best_model.predict_proba(X_test)[:, 1]


    #metrics

    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    print("ROC-AUC:", roc_auc_score(y_test, y_proba))
# Out:
# 1470
#
#  LogisticRegression
# Best params: {'model__C': 1}
# Best score: 0.8183613291470435
#
# Confusion Matrix:
# [[244  11]
#  [ 25  14]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       255
#            1       0.56      0.36      0.44        39
#
#     accuracy                           0.88       294
#    macro avg       0.73      0.66      0.68       294
# weighted avg       0.86      0.88      0.87       294
#
# ROC-AUC: 0.7520361990950227
#
#  RandomForest
# Best params: {'model__criterion': 'entropy', 'model__max_depth': 8, 'model__n_estimators': 200}
# Best score: 0.8103483778126634
#
# Confusion Matrix:
# [[253   2]
#  [ 35   4]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       255
#            1       0.67      0.10      0.18        39
#
#     accuracy                           0.87       294
# ...

# %%
fpr, tpr, _ = roc_curve(y_test, y_proba)

plt.figure()
plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc_score(y_test, y_proba):.2f})")
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title(f"ROC Curve - {name}")
plt.legend()
plt.show()

# %%
import joblib
print(best_model.feature_names_in_)
best_model = grid_search.best_estimator_

joblib.dump(best_model, "attrition_model.pkl")
# Out:
# ['Age' 'BusinessTravel' 'Department' 'Education' 'EducationField'
#  'EnvironmentSatisfaction' 'Gender' 'JobInvolvement' 'JobLevel' 'JobRole'
#  'JobSatisfaction' 'MaritalStatus' 'MonthlyIncome' 'Over18' 'OverTime'
#  'PerformanceRating' 'RelationshipSatisfaction' 'StockOptionLevel'
#  'TotalWorkingYears' 'WorkLifeBalance' 'YearsAtCompany'
#  'YearsInCurrentRole' 'YearsWithCurrManager']
# ['attrition_model.pkl']
